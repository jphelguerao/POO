# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
d= pd.read_csv("/content/drive/MyDrive/database/ETF prices.csv")
d
# Out:
#         fund_symbol  price_date   open   high    low  close  adj_close  volume
# 0               AAA  2020-09-09  25.10  25.12  25.07  25.07      24.85   17300
# 1               AAA  2020-09-10  25.06  25.07  25.05  25.07      24.85   23500
# 2               AAA  2020-09-11  25.04  25.05  25.02  25.03      24.81   33400
# 3               AAA  2020-09-14  25.01  25.06  25.01  25.02      24.80   13100
# 4               AAA  2020-09-15  25.02  25.03  25.01  25.01      24.79   12100
# ...             ...         ...    ...    ...    ...    ...        ...     ...
# 3866025         ZSL  2021-11-23  26.81  27.21  26.30  26.35      26.35  190900
# 3866026         ZSL  2021-11-24  26.79  26.96  26.57  26.69      26.69  109000
# 3866027         ZSL  2021-11-26  26.67  28.14  26.67  27.72      27.72  205500
# 3866028         ZSL  2021-11-29  27.89  28.56  27.80  28.27      28.27  411900
# 3866029         ZSL  2021-11-30  28.15  28.73  25.91  28.49      28.49  219400
#
# ...

# %%
d.shape
# Out:
# (3866030, 8)

# %%
d= d.drop(columns=["high", "low"])

# %%
d.iloc[0:100]
# Out:
#    fund_symbol  price_date   open  close  adj_close  volume
# 0          AAA  2020-09-09  25.10  25.07      24.85   17300
# 1          AAA  2020-09-10  25.06  25.07      24.85   23500
# 2          AAA  2020-09-11  25.04  25.03      24.81   33400
# 3          AAA  2020-09-14  25.01  25.02      24.80   13100
# 4          AAA  2020-09-15  25.02  25.01      24.79   12100
# ..         ...         ...    ...    ...        ...     ...
# 95         AAA  2021-01-26  25.16  25.17      25.02     500
# 96         AAA  2021-01-27  25.14  25.15      25.01     500
# 97         AAA  2021-01-28  25.15  25.15      25.01     200
# 98         AAA  2021-01-29  25.16  25.15      25.00    3100
# 99         AAA  2021-02-01  25.14  25.13      25.01    1300
#
# [100 rows x 6 columns]

# %%
d.iloc[:, [1,2,5]]
# Out:
#          price_date   open  volume
# 0        2020-09-09  25.10   17300
# 1        2020-09-10  25.06   23500
# 2        2020-09-11  25.04   33400
# 3        2020-09-14  25.01   13100
# 4        2020-09-15  25.02   12100
# ...             ...    ...     ...
# 3866025  2021-11-23  26.81  190900
# 3866026  2021-11-24  26.79  109000
# 3866027  2021-11-26  26.67  205500
# 3866028  2021-11-29  27.89  411900
# 3866029  2021-11-30  28.15  219400
#
# [3866030 rows x 3 columns]

# %%
import numpy as np

# %%
precios = np.random.rand(10)
closed= np.random.randint(1,100,10)
closed

# %%
diccionario={"precios":precios,"cierre":closed}
precio=pd.DataFrame(diccionario)
precio
# Out:
#     precios  cierre
# 0  0.809826      62
# 1  0.149629      70
# 2  0.905068      17
# 3  0.238622      18
# 4  0.263804      44
# 5  0.895516      26
# 6  0.421618      62
# 7  0.052972      57
# 8  0.032171      92
# 9  0.184533      23

# %%
precio[precio['cierre']>70]
# Out:
#     precios  cierre
# 8  0.032171      92

# %%
d['adj_close'].value_counts()
# Out:
# 25.10       1671
# 25.00       1627
# 24.75       1584
# 25.30       1570
# 25.11       1557
#             ...
# 27239.13       1
# 26429.86       1
# 25600.84       1
# 23863.85       1
# 223.42         1
# Name: adj_close, Length: 103566, dtype: int64

# %%
d.describe()
# Out:
#                open         close     adj_close        volume
# count  3.866030e+06  3.866030e+06  3.866030e+06  3.866030e+06
# mean   1.202537e+05  1.196726e+05  1.196579e+05  1.026745e+06
# std    1.149917e+07  1.143655e+07  1.143655e+07  1.275733e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.486000e+01  2.485000e+01  2.229000e+01  3.553000e+03
# 50%    3.388000e+01  3.387000e+01  3.108000e+01  2.133900e+04
# 75%    5.417000e+01  5.416000e+01  5.007000e+01  1.269000e+05
# max    2.656750e+09  2.808750e+09  2.808750e+09  2.987062e+09
